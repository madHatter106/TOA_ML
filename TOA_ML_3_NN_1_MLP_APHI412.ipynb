# %%
from IPython.core.display import HTML, display
from collections import namedtuple as NT

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold, LeaveOneOut
from sklearn.metrics import r2_score, mean_absolute_error
import matplotlib.pyplot as pl
from matplotlib import rcParams

from keras import models
from keras.layers import Dense, Conv1D, MaxPool1D, Dropout
from keras import regularizers
from keras.optimizers import Adam
from keras.wrappers.scikit_learn import KerasRegressor
from keras.utils import plot_model
from tqdm import tnrange, tqdm_notebook
# Out:
# Using TensorFlow backend.

# %%
display(HTML("<style>.container {width:90% !important}</style>"))
# Out:
# <style>.container {width:90% !important}</style>

# %%
% matplotlib inline
rcParams['axes.labelsize'] = 16
rcParams['xtick.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['font.size'] = 16
rcParams['axes.titlesize'] = 18
rcParams['figure.titlesize'] = 20

# %%
band = 411
d_ = pd.read_pickle('./pickleJar/OperationalDataSets/df_6_APHY_Standardized_SWF_SAT.pkl')

# %%
d_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162 entries, 2 to 494
# Data columns (total 28 columns):
# oisst_s            162 non-null float64
# solz_s             162 non-null float64
# sat_rho_rc412_s    162 non-null float64
# sat_rho_rc443_s    162 non-null float64
# sat_rho_rc490_s    162 non-null float64
# sat_rho_rc510_s    162 non-null float64
# sat_rho_rc555_s    162 non-null float64
# sat_rho_rc670_s    162 non-null float64
# log10_etopo2_s     162 non-null float64
# sin_doy_s          162 non-null float64
# cos_doy_s          162 non-null float64
# sin_minofday_s     162 non-null float64
# cos_minofday_s     162 non-null float64
# x_s                162 non-null float64
# y_s                162 non-null float64
# z_s                162 non-null float64
# aphy411            162 non-null float64
# aphy443            162 non-null float64
# aphy489            162 non-null float64
# aphy510            162 non-null float64
# aphy555            162 non-null float64
# aphy670            162 non-null float64
# log10_aphy411      162 non-null float64
# log10_aphy443      162 non-null float64
# log10_aphy489      162 non-null float64
# log10_aphy510      162 non-null float64
# log10_aphy555      162 non-null float64
# log10_aphy670      162 non-null float64
# dtypes: float64(28)
# memory usage: 36.7 KB

# %%
X_sat = d_.dropna().filter(regex='sat')
y = d_.dropna().loc[:, 'log10_aphy%d' % band]

# %%
assert X_sat.shape[0] == y.size

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sat, y, test_size=0.1, random_state=42)

# %%
def build_MLP_model(layers=1,n_hidden=256):
    model = models.Sequential()
    model.add(Dense(n_hidden, activation='relu',
                    kernel_regularizer=regularizers.l1(0.001),
                    input_shape=(X_train.shape[1],) )
             )
    if layers == 2:
        model.add(Dense(n_hidden, kernel_regularizer=regularizers.l1(0.001),
                        activation='relu')
                 )
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model


def build_CNN_model():
    l1_decay = 0.00001
    model = models.Sequential()
    model.add(Conv1D(128, kernel_size=(5,1), strides=4,
                    kernel_regularizer=regularizers.l1(l1_decay)))
    model.add(Dropout(0.5))
    model.add(Conv1D(64, kernel_size=(5, 1), strides=4))
    model.add(Dropout(0.5))
    model.add(Conv1D(32, kernel_size=(5, 1), strides=4))
    model.add(Dropout(0.5))
    model.add(Dense(163, activation='relu', kernel_regularizer=regularizers.l1(l1_decay)))
    model.add(Dense(163, activation='relu', kernel_regularizer=regularizers.l1(l1_decay)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

def smooth(points, factor=0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %% [markdown]
# Given the small size of the data set, I will use k-fold validation to train the model.

# %%
def Cross_Fold_Validation(X_, y_, model_, k=4, num_epochs=100, verbose=0):
    results = dict(fold_val_mae=[], fold_val_mse=[],
                   val_mae_histories=[], train_mae_histories=[])
    kfold = KFold(n_splits=k, )
    for train_idx, val_idx in kfold.split(X_):
        history = model_.fit(X_[train_idx], y_[train_idx], epochs=num_epochs,
                            validation_data=(X_[val_idx], y_[val_idx]),
                            batch_size=1,  verbose=verbose)
        val_mse, val_mae = model_.evaluate(X_[val_idx], y_[val_idx], verbose=0)
        results['fold_val_mae'].append(val_mae)
        results['fold_val_mse'].append(val_mse)
        results['val_mae_histories'].append(history.history['val_mean_absolute_error'])
        results['train_mae_histories'].append(history.history['mean_absolute_error'])
    return results


def LOO_Validation(X_, y_, model_, num_epochs=100, verbose=0):
    results = dict(fold_val_mae=[], fold_val_mse=[],
                   val_mae_histories=[], train_mae_histories=[])
    loo = LeaveOneOut()
    for train_idx, val_idx in loo.split(X_):
        history = model_.fit(X_[train_idx], y_[train_idx], epochs=num_epochs,
                            validation_data=(X_[val_idx], y_[val_idx]),
                            batch_size=1, verbose=verbose)
        val_mse, val_mae = model_.evaluate(X_[val_idx], y_[val_idx], verbose=0)
        results['fold_val_mae'].append(val_mae)
        results['fold_val_mse'].append(val_mse)
        results['val_mae_histories'].append(history.history['val_mean_absolute_error'])
        results['train_mae_histories'].append(history.history['mean_absolute_error'])
    return results


def plot_mae_history(train_mae_histories, val_mae_histories, smoothed=True):
    n_epochs = len(train_mae_histories[0])
    avg_val_mae_history = [np.mean([x[i] for x in val_mae_histories])
                           for i in range(n_epochs)]
    avg_train_mae_history = [np.mean([x[i] for x in train_mae_histories])
                           for i in range(n_epochs)]
    if smoothed:
        avg_val_mae_history = smooth(avg_val_mae_history)
        avg_train_mae_history = smooth(avg_train_mae_history)
        
    pl.plot(range(1, len(avg_val_mae_history) + 1), avg_val_mae_history, label='val')
    pl.plot(range(1, len(avg_train_mae_history) + 1), avg_train_mae_history, label='train',
           color='r')
    pl.xlabel('Epochs')
    pl.ylabel('MAE');
    
def plot_fits(model_,):
    y_pred = model_.predict(X_test)
    _, ax = pl.subplots(figsize=(10, 10))
    r2_  = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred, )
    min_ = min(y_pred.min(), y_test.min())
    max_ = max(y_pred.max(), y_test.max())
    ax.plot([min_, max_],[min_, max_], ls='--', color='k', label='1:1')
    ax.scatter(y_pred, y_test, label='$r^2$ = %.2f, mae = %.2f' %(r2_, mae))
    ax.set_xlabel('predicted')
    ax.set_ylabel=('observed')
    ax.legend()
    ax.set_title('MLP - Test Data')

    
def plot_fits_2(model_,):
    y_pred = model_.predict(X_test.values)
    ix = np.argsort(y_test)
    xi = np.arange(ix.size)
    _, ax = pl.subplots(figsize=(12, 8))
    ax.scatter(xi, y_test.values[ix], color='steelblue', edgecolor='k', s=50, label='observed')
    ax.scatter(xi, y_pred[ix], color='m', edgecolor='k', s=50, label='predicted')
    ax.legend();

# %% [markdown]
# ### Single Layer Models
# #### 1. <u>4-Fold Cross-Validation</u>

# %%
X_train_ = X_train.values
y_train_ = y_train.values

# %%
model_L1NN_KCV = build_MLP_model()

# %%
model_L1NN_KCV.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               1792
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,049
# Trainable params: 2,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 1000
results_l1nn_kcv = Cross_Fold_Validation(X_train_, y_train_, model_=model_L1NN_KCV,
                                        num_epochs=num_epochs)

# %%
results_l1nn_kcv['fold_val_mae']
# Out:
# [0.11803691773801236,
#  0.12760410375065273,
#  0.1220252580112881,
#  0.09561989704767863]

# %%
plot_mae_history(results_l1nn_kcv['train_mae_histories'], results_l1nn_kcv['val_mae_histories'])

# %%
test_mse_score, test_mae_score = model_L1NN_KCV.evaluate(X_test, y_test)
np.sqrt(test_mse_score), test_mae_score
# Out:
# 17/17 [==============================] - 0s 42us/step
# (0.15194406408836317, 0.10907687991857529)

# %%
plot_fits(model_L1NN_KCV)

# %%
plot_fits_2(model_L1NN_KCV)

# %% [markdown]
# #### 2. <u>Leave-One-Out Cross-Validation</u>

# %%
model_L1NN_LOO = build_MLP_model(n_hidden=16)
results_l1nn_loo = LOO_Validation(X_train_, y_train_, model_=model_L1NN_LOO)

# %%
results_l1nn_kcv['fold_val_mae'], results_l1nn_loo['fold_val_mae']
# Out:
# ([0.11803691773801236,
#   0.12760410375065273,
#   0.1220252580112881,
#   0.09561989704767863],
#  [0.12133383750915527,
#   0.06526386737823486,
#   0.10370898246765137,
#   0.1364496946334839,
#   0.05565774440765381,
#   0.11870288848876953,
#   0.039822936058044434,
#   0.041155219078063965,
#   0.06923854351043701,
#   0.010463595390319824,
#   0.08089959621429443,
#   0.2468324899673462,
#   0.004649758338928223,
#   0.06919023394584656,
#   0.06450426578521729,
#   0.024373292922973633,
#   0.19817590713500977,
#   0.3253159523010254,
#   0.10562753677368164,
#   0.009701728820800781,
#   0.01616644859313965,
#   0.12330520153045654,
#   0.10203003883361816,
#   0.07863116264343262,
#   0.0796668529510498,
#   0.15103650093078613,
#   0.09183025360107422,
#   0.013204336166381836,
#   0.2525792121887207,
#   0.06209677457809448,
#   0.021082282066345215,
#   0.06991374492645264,
#   0.029334664344787598,
#   0.014653921127319336,
#   0.08284544944763184,
#   0.015414237976074219,
#   0.10998761653900146,
#   0.14324790239334106,
#   0.17183589935302734,
#   0.19342339038848877,
#   0.1125645637512207,
#   0.06921732425689697,
#   0.09887266159057617,
#   0.28060007095336914,
#   0.07096843421459198,
#   0.08668708801269531,
#   0.25226640701293945,
#   0.15240979194641113,
#   0.062039971351623535,
#   0.21332108974456787,
#   0.016205787658691406,
#   0.08221471309661865,
#   0.005372166633605957,
#   0.09386146068572998,
#   0.1304628849029541,
#   0.01868462562561035,
#   0.09305644035339355,
#   0.12625861167907715,
#   0.0687183141708374,
#   0.00973212718963623,
#   0.12771975994110107,
#   0.02783668041229248,
#   0.08543074131011963,
#   0.2878751754760742,
#   0.03843247890472412,
#   0.11131203174591064,
#   0.21089231967926025,
#   0.0574948787689209,
#   0.03148841857910156,
#   0.013087272644042969,
#   0.10931026935577393,
#   0.10321807861328125,
#   0.046607255935668945,
#   0.22547590732574463,
#   0.03372526168823242,
#   0.21052026748657227,
#   0.17671597003936768,
#   0.2681570053100586,
#   0.050983309745788574,
#   0.17556732892990112,
#   0.22856783866882324,
#   0.2308495044708252,
#   0.09624671936035156,
#   0.1863442063331604,
#   0.031146883964538574,
#   0.17102038860321045,
#   0.11560869216918945,
#   0.027269601821899414,
#   0.008221745491027832,
#   0.04292166233062744,
#   0.06872928142547607,
#   0.050344109535217285,
#   0.00431370735168457,
#   0.024897456169128418,
#   0.5934066772460938,
#   0.22229671478271484,
#   0.06139421463012695,
#   0.365437388420105,
#   0.06673634052276611,
#   0.015914320945739746,
#   0.10639524459838867,
#   0.012643575668334961,
#   0.09722566604614258,
#   0.1177206039428711,
#   0.018474221229553223,
#   0.02843773365020752,
#   0.13107061386108398,
#   0.15407061576843262,
#   0.24488291144371033,
#   0.025396347045898438,
#   0.00299835205078125,
#   0.06509137153625488,
#   0.1128467321395874,
#   0.1352095603942871,
#   0.3112459182739258,
#   0.025770187377929688,
#   0.0066471099853515625,
#   0.17580103874206543,
#   0.12129354476928711,
#   0.18144643306732178,
#   0.07077765464782715,
#   0.01727759838104248,
#   0.24800336360931396,
#   0.0018521547317504883,
#   0.09181392192840576,
#   0.18063652515411377,
#   0.0634150505065918,
#   0.17980444431304932,
#   0.03706181049346924,
#   0.11010801792144775,
#   0.13309431076049805,
#   0.09910798072814941,
#   0.06839776039123535,
#   0.026201486587524414,
#   0.25651979446411133,
#   0.039255619049072266,
#   0.29665911197662354,
#   0.03973233699798584,
#   0.033332228660583496,
#   0.08676469326019287,
#   0.06575727462768555,
#   0.04575085639953613,
#   0.037732601165771484,
#   0.019094347953796387,
#   0.08868086338043213])

# %%
plot_mae_history(results_l1nn_loo['train_mae_histories'], results_l1nn_loo['val_mae_histories'],
                 smoothed=True)

# %%
test_mse_score_loo, test_mae_score_loo = model_L1NN_LOO.evaluate(X_test, y_test)
np.sqrt(test_mse_score_loo), test_mae_score_loo
# Out:
# 17/17 [==============================] - 0s 42us/step
# (0.1456727494800003, 0.11312883347272873)

# %%
plot_fits(model_L1NN_LOO)

# %%
plot_fits_2(model_L1NN_LOO)

# %% [markdown]
# ### 2-Layer MLP

# %%
model_L2NN_KCV = build_MLP_model(layers=2)
results_l2nn_kcv = Cross_Fold_Validation(X_train_, y_train_, model_=model_L2NN_KCV, num_epochs=num_epochs)

# %%
np.mean(results_l1nn_kcv['fold_val_mae']), np.mean(results_l2nn_kcv['fold_val_mae'])
# Out:
# (0.11582154413690797, 0.12468380581688236)

# %%
plot_mae_history(results_l2nn_kcv['train_mae_histories'], results_l2nn_kcv['val_mae_histories'])

# %%
plot_fits(model_L2NN_KCV)

# %%
plot_fits_2(model_L2NN_KCV)
