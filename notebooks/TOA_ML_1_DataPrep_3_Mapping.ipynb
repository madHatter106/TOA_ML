# %%
from IPython.core.display import HTML, display
import pandas as pd
import numpy as np

import matplotlib.pyplot as pl
import cartopy.crs as ccrs

# %%
display(HTML("<style>.container {width: 90% !important}</style>"))
# Out:
# <style>.container {width: 90% !important}</style>

# %%
% matplotlib inline

# %%
df = pd.read_pickle('./pickleJar/DevelopmentalDataSets/df_4_ML4aph.pkl')
dfs = pd.read_pickle('./pickleJar/DevelopmentalDataSets/df_4_ML4chl.pkl')

# %%
df.head().T
# Out:
#                                  0                    1                    2  \
# oisst                        19.57                 2.54                 0.78
# etopo2                         462                 3549                  330
# solz                          48.7                 51.2                 52.7
# sat_rho_rc412            0.0120876            0.0105251           0.00444289
# sat_rho_rc443            0.0124167            0.0106362           0.00438667
# sat_rho_rc490            0.0117387           0.00961355           0.00424045
# sat_rho_rc510            0.0105793            0.0079127            0.0036856
# sat_rho_rc555            0.0091096            0.0062244            0.0026462
# sat_rho_rc670            0.0066549             0.004794            0.0011773
# datetime       1997-10-11 09:32:00  2000-02-22 17:00:00  2001-02-19 16:10:00
# lat                          39.29               -61.45               -61.29
# ...

# %%
dfs.head().T
# Out:
#                                  0                    1                    2  \
# datetime       1997-10-11 09:32:00  2000-02-22 17:00:00  2001-02-19 16:10:00
# lat                          39.29               -61.45               -61.29
# lon                          25.11              -62.299               -56.29
# oisst                        19.57                 2.54                 0.78
# etopo2                         462                 3549                  330
# solz                          48.7                 51.2                 52.7
# sat_rho_rc412            0.0120876            0.0105251           0.00444289
# sat_rho_rc443            0.0124167            0.0106362           0.00438667
# sat_rho_rc490            0.0117387           0.00961355           0.00424045
# sat_rho_rc510            0.0105793            0.0079127            0.0036856
# sat_rho_rc555            0.0091096            0.0062244            0.0026462
# ...

# %%
subplot_kw = dict(projection=ccrs.PlateCarree())
f, ax = pl.subplots(figsize=(14, 22),
                   subplot_kw=subplot_kw)
ax.background_patch.set_visible(False)
ax.outline_patch.set_visible(False)
ax.stock_img()
ax.coastlines()
ax.scatter(df.lon, df.lat, color='red', edgecolor='k', alpha=0.75, lw=2)
#ax.scatter(dfs.lon, dfs.lat, color='orange', edgecolor='k', alpha=0.75, lw=2)
#f.savefig('./figJar/map.pdf', dpi=300, format='pdf', bbox_inches='tight')

# %%
pl.show()
