# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as pl
from matplotlib import rcParams
from seaborn import pairplot

# %%
# %matplotlib inline
rcParams['axes.titlesize'] = 18
rcParams['xtick.labelsize'] = 16
rcParams['axes.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['font.size'] = 16

# %%
def is_in_polygon(row):
    pnt = Point(row.lon, row.lat)
    dist_dict = {}
    for pcat, coords in zip (dl.ProvCat, dl.coords):
        poly = Polygon(coords)
        if pnt.within(poly):
            return pcat
        else:
            dist_dict[pcat] = poly.distance(pnt)
    return min(dist_dict, key=dist_dict.get)

def get_addnl_loc_data(row, col):
    return dl.loc[dl.ProvCat == row.ProvCat, col].values[0]

# %%
df_chl = pd.read_pickle('./pickleJar/df_4_ML4chl.pkl')

# %%
dl = pd.read_pickle('./pickleJar/d_longhurst.pkl')

# %%
df_chl.head()
# Out:
#              datetime      lat      lon  oisst  etopo2  solz  sat_rho_rc412  \
# 0 1997-10-11 09:32:00  39.2900  25.1100  19.57   462.0  48.7       0.012088
# 1 2000-02-22 17:00:00 -61.4500 -62.2990   2.54  3549.0  51.2       0.010525
# 2 2001-02-19 16:10:00 -61.2900 -56.2900   0.78   330.0  52.7       0.004443
# 3 2002-01-22 13:45:00 -60.9990 -56.4980   1.79  2193.0  45.9       0.005869
# 4 1997-09-27 11:29:00  24.1392 -20.9995  24.67  4369.0  28.0       0.009464
#
#    sat_rho_rc443  sat_rho_rc490  sat_rho_rc510  sat_rho_rc555  sat_rho_rc670  \
# 0       0.012417       0.011739       0.010579       0.009110       0.006655
# 1       0.010636       0.009614       0.007913       0.006224       0.004794
# 2       0.004387       0.004240       0.003686       0.002646       0.001177
# 3       0.005866       0.005535       0.004643       0.003326       0.001747
# 4       0.008968       0.007719       0.005974       0.004161       0.002517
#
#    chl_fluo  chl_hplc    chl  log10_chl  is_hplc
# 0     0.091       NaN  0.091  -1.040959    False
# 1     0.132     0.118  0.118  -0.928118     True
# 2       NaN       NaN    NaN        NaN    False
# 3     0.707     0.614  0.614  -0.211832     True
# 4       NaN     0.158  0.158  -0.801343     True

# %%
df_chl[df_chl.sat_rho_rc412==0]
# Out:
#                datetime     lat     lon  oisst  etopo2  solz  sat_rho_rc412  \
# 174 2001-08-28 20:05:00  27.236 -83.469   29.9    42.0  20.3            0.0
#
#      sat_rho_rc443  sat_rho_rc490  sat_rho_rc510  sat_rho_rc555  \
# 174            0.0            0.0            0.0            0.0
#
#      sat_rho_rc670  chl_fluo  chl_hplc      chl  log10_chl  is_hplc
# 174            0.0   0.14052       NaN  0.14052  -0.852262    False

# %%
df_chl.insert(df_chl.columns.get_loc('lon')+1, 'ProvCat',
              df_chl.apply(is_in_polygon, axis=1))

# %%
df_chl.head()
# Out:
#              datetime      lat      lon  ProvCat  oisst  etopo2  solz  \
# 0 1997-10-11 09:32:00  39.2900  25.1100       42  19.57   462.0  48.7
# 1 2000-02-22 17:00:00 -61.4500 -62.2990       22   2.54  3549.0  51.2
# 2 2001-02-19 16:10:00 -61.2900 -56.2900       25   0.78   330.0  52.7
# 3 2002-01-22 13:45:00 -60.9990 -56.4980       25   1.79  2193.0  45.9
# 4 1997-09-27 11:29:00  24.1392 -20.9995       33  24.67  4369.0  28.0
#
#    sat_rho_rc412  sat_rho_rc443  sat_rho_rc490  sat_rho_rc510  sat_rho_rc555  \
# 0       0.012088       0.012417       0.011739       0.010579       0.009110
# 1       0.010525       0.010636       0.009614       0.007913       0.006224
# 2       0.004443       0.004387       0.004240       0.003686       0.002646
# 3       0.005869       0.005866       0.005535       0.004643       0.003326
# 4       0.009464       0.008968       0.007719       0.005974       0.004161
#
#    sat_rho_rc670  chl_fluo  chl_hplc    chl  log10_chl  is_hplc
# 0       0.006655     0.091       NaN  0.091  -1.040959    False
# 1       0.004794     0.132     0.118  0.118  -0.928118     True
# 2       0.001177       NaN       NaN    NaN        NaN    False
# 3       0.001747     0.707     0.614  0.614  -0.211832     True
# 4       0.002517       NaN     0.158  0.158  -0.801343     True

# %%
dl_cols_to_xtract = ['Biome', 'BiomCat', 'Province', 'ProvCode', 'ProvCat']

# %%
dl.loc[dl.ProvCat==2, dl_cols_to_xtract]
# Out:
#      Biome  BiomCat                           Province ProvCode  ProvCat
# 2  Coastal        0  Benguela Current Coastal Province     BENG        2

# %%
df = df_chl.copy()

# %%
for col in dl_cols_to_xtract[:-1]:
    print(col)
    df.insert(df.columns.get_loc('ProvCat'), col,
              df.apply(get_addnl_loc_data, col=col, axis=1))
# Out:
# Biome
# BiomCat
# Province
# ProvCode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 495 entries, 0 to 494
# Data columns (total 22 columns):
# datetime         495 non-null datetime64[ns]
# lat              495 non-null float64
# lon              495 non-null float64
# Biome            495 non-null object
# BiomCat          495 non-null int64
# Province         495 non-null object
# ProvCode         495 non-null object
# ProvCat          495 non-null int64
# oisst            495 non-null float64
# etopo2           495 non-null float64
# solz             495 non-null float64
# sat_rho_rc412    495 non-null float64
# sat_rho_rc443    495 non-null float64
# sat_rho_rc490    495 non-null float64
# sat_rho_rc510    495 non-null float64
# sat_rho_rc555    495 non-null float64
# sat_rho_rc670    495 non-null float64
# chl_fluo         364 non-null float64
# chl_hplc         158 non-null float64
# chl              424 non-null float64
# log10_chl        424 non-null float64
# is_hplc          495 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(15), int64(2), object(3)
# memory usage: 85.6+ KB

# %%
df.loc[df.sat_rho_rc412==0]
# Out:
#                datetime     lat     lon       Biome  BiomCat  \
# 174 2001-08-28 20:05:00  27.236 -83.469  Westerlies        3
#
#                                         Province ProvCode  ProvCat  oisst  \
# 174  N. Pacific Subtropical Gyre Province (West)     NPSW       47   29.9
#
#      etopo2   ...     sat_rho_rc443  sat_rho_rc490  sat_rho_rc510  \
# 174    42.0   ...               0.0            0.0            0.0
#
#      sat_rho_rc555  sat_rho_rc670  chl_fluo  chl_hplc      chl  log10_chl  \
# 174            0.0            0.0   0.14052       NaN  0.14052  -0.852262
#
#      is_hplc
# 174    False
#
# [1 rows x 22 columns]

# %%
df.drop(index=174, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 494 entries, 0 to 494
# Data columns (total 22 columns):
# datetime         494 non-null datetime64[ns]
# lat              494 non-null float64
# lon              494 non-null float64
# Biome            494 non-null object
# BiomCat          494 non-null int64
# Province         494 non-null object
# ProvCode         494 non-null object
# ProvCat          494 non-null int64
# oisst            494 non-null float64
# etopo2           494 non-null float64
# solz             494 non-null float64
# sat_rho_rc412    494 non-null float64
# sat_rho_rc443    494 non-null float64
# sat_rho_rc490    494 non-null float64
# sat_rho_rc510    494 non-null float64
# sat_rho_rc555    494 non-null float64
# sat_rho_rc670    494 non-null float64
# chl_fluo         363 non-null float64
# chl_hplc         158 non-null float64
# chl              423 non-null float64
# log10_chl        423 non-null float64
# is_hplc          494 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(15), int64(2), object(3)
# memory usage: 85.4+ KB

# %%
df.describe().T
# Out:
#                count        mean          std         min        25%  \
# lat            494.0   28.890834    20.609094  -67.643000  26.936650
# lon            494.0  -70.934556    41.550826 -170.198000 -83.386450
# BiomCat        494.0    1.536437     1.375565    0.000000   0.000000
# ProvCat        494.0   28.882591    16.174203    2.000000  17.000000
# oisst          494.0   19.044089     6.973292    0.780000  13.772500
# etopo2         494.0  770.433198  1411.802763    0.000000  20.250000
# solz           494.0   31.314170    14.531983    0.000000  20.700000
# sat_rho_rc412  494.0    0.006756     0.003868    0.001360   0.003726
# sat_rho_rc443  494.0    0.007039     0.003629    0.001656   0.004210
# sat_rho_rc490  494.0    0.007258     0.003441    0.001897   0.004528
# sat_rho_rc510  494.0    0.006747     0.003339    0.001890   0.004140
# sat_rho_rc555  494.0    0.006182     0.003519    0.001690   0.003433
# sat_rho_rc670  494.0    0.003545     0.002455    0.000531   0.001682
# chl_fluo       363.0    1.416348     3.219245    0.025000   0.206000
# chl_hplc       158.0    2.324667     4.019108    0.027000   0.221500
# chl            423.0    1.635382     3.527198    0.025000   0.198850
# log10_chl      423.0   -0.240235     0.605531   -1.602060  -0.701477
#
#                       50%         75%          max
# lat             32.410000   42.352250    79.000000
# lon            -75.961200  -66.998500   171.716000
# BiomCat          2.000000    3.000000     3.000000
# ProvCat         29.000000   46.000000    50.000000
# oisst           19.600000   25.027500    30.510000
# etopo2         156.000000  519.500000  5529.000000
# solz            32.300000   42.650000    69.900000
# sat_rho_rc412    0.005999    0.008869     0.020979
# sat_rho_rc443    0.006646    0.008943     0.020130
# sat_rho_rc490    0.006869    0.009147     0.018906
# sat_rho_rc510    0.005863    0.008762     0.018512
# sat_rho_rc555    0.005139    0.008000     0.019804
# sat_rho_rc670    0.002747    0.004736     0.011320
# chl_fluo         0.516100    1.237450    43.100000
# chl_hplc         0.815785    2.170500    23.984000
# chl              0.535410    1.381735    43.100000
# log10_chl       -0.271314    0.140423     1.634477

# %%
def is_coastal(row):
    if row['Biome'] == 'Coastal':
        return 1
    else:
        return 0

# %%
df.insert(df.columns.get_loc('ProvCat'), 'Coastal', df.apply(is_coastal, axis=1))

# %%
df.head()
# Out:
#              datetime      lat      lon       Biome  BiomCat  \
# 0 1997-10-11 09:32:00  39.2900  25.1100  Westerlies        3
# 1 2000-02-22 17:00:00 -61.4500 -62.2990       Polar        1
# 2 2001-02-19 16:10:00 -61.2900 -56.2900       Polar        1
# 3 2002-01-22 13:45:00 -60.9990 -56.4980       Polar        1
# 4 1997-09-27 11:29:00  24.1392 -20.9995      Trades        2
#
#                                      Province ProvCode  Coastal  ProvCat  \
# 0       Mediterranean Sea, Black Sea Province     MEDI        0       42
# 1                          Antarctic Province     ANTA        0       22
# 2                      Austral Polar Province     APLR        0       25
# 3                      Austral Polar Province     APLR        0       25
# 4  N. Atlantic Tropical Gyral Province (Trpg)     NATR        0       33
#
#    oisst   ...     sat_rho_rc443  sat_rho_rc490  sat_rho_rc510  sat_rho_rc555  \
# 0  19.57   ...          0.012417       0.011739       0.010579       0.009110
# 1   2.54   ...          0.010636       0.009614       0.007913       0.006224
# 2   0.78   ...          0.004387       0.004240       0.003686       0.002646
# 3   1.79   ...          0.005866       0.005535       0.004643       0.003326
# 4  24.67   ...          0.008968       0.007719       0.005974       0.004161
#
#    sat_rho_rc670  chl_fluo  chl_hplc    chl  log10_chl  is_hplc
# 0       0.006655     0.091       NaN  0.091  -1.040959    False
# 1       0.004794     0.132     0.118  0.118  -0.928118     True
# 2       0.001177       NaN       NaN    NaN        NaN    False
# 3       0.001747     0.707     0.614  0.614  -0.211832     True
# 4       0.002517       NaN     0.158  0.158  -0.801343     True
#
# [5 rows x 23 columns]

# %%
df.head()
# Out:
#              datetime      lat      lon       Biome  BiomCat  \
# 0 1997-10-11 09:32:00  39.2900  25.1100  Westerlies        3
# 1 2000-02-22 17:00:00 -61.4500 -62.2990       Polar        1
# 2 2001-02-19 16:10:00 -61.2900 -56.2900       Polar        1
# 3 2002-01-22 13:45:00 -60.9990 -56.4980       Polar        1
# 4 1997-09-27 11:29:00  24.1392 -20.9995      Trades        2
#
#                                      Province ProvCode  Coastal  ProvCat  \
# 0       Mediterranean Sea, Black Sea Province     MEDI        0       42
# 1                          Antarctic Province     ANTA        0       22
# 2                      Austral Polar Province     APLR        0       25
# 3                      Austral Polar Province     APLR        0       25
# 4  N. Atlantic Tropical Gyral Province (Trpg)     NATR        0       33
#
#    oisst   ...     sat_rho_rc443  sat_rho_rc490  sat_rho_rc510  sat_rho_rc555  \
# 0  19.57   ...          0.012417       0.011739       0.010579       0.009110
# 1   2.54   ...          0.010636       0.009614       0.007913       0.006224
# 2   0.78   ...          0.004387       0.004240       0.003686       0.002646
# 3   1.79   ...          0.005866       0.005535       0.004643       0.003326
# 4  24.67   ...          0.008968       0.007719       0.005974       0.004161
#
#    sat_rho_rc670  chl_fluo  chl_hplc    chl  log10_chl  is_hplc
# 0       0.006655     0.091       NaN  0.091  -1.040959    False
# 1       0.004794     0.132     0.118  0.118  -0.928118     True
# 2       0.001177       NaN       NaN    NaN        NaN    False
# 3       0.001747     0.707     0.614  0.614  -0.211832     True
# 4       0.002517       NaN     0.158  0.158  -0.801343     True
#
# [5 rows x 23 columns]

# %%
df.Biome.value_counts()
# Out:
# Coastal       206
# Westerlies    199
# Trades         73
# Polar          16
# Name: Biome, dtype: int64

# %%
df.Coastal.value_counts()
# Out:
# 0    288
# 1    206
# Name: Coastal, dtype: int64

# %%
df.to_pickle('./pickleJar/df_4_AllFeatures_n_Longhurst.pkl')

# %%
pg = pairplot(df[['oisst', 'log10_chl',  'Coastal']],
              vars=['oisst', 'log10_chl'], hue='Coastal', height=12,
              plot_kws={'s': 150})
pl.rcParams.update(**rcParams)

# %%
sb.pairplot(df[['oisst', 'log10_chl',  'Biome']], 
            vars=['oisst', 'log10_chl'], hue='Biome', height=12,
           plot_kws={'s': 150});

# %%
df = pd.read_pickle('./pickleJar/df_4_AllFeatures_n_Longhurst.pkl')

# %%
df.head().T
# Out:
#                                                    0                    1  \
# datetime                         1997-10-11 09:32:00  2000-02-22 17:00:00
# lat                                            39.29               -61.45
# lon                                            25.11              -62.299
# Biome                                     Westerlies                Polar
# BiomCat                                            3                    1
# Province       Mediterranean Sea, Black Sea Province   Antarctic Province
# ProvCode                                        MEDI                 ANTA
# Coastal                                            0                    0
# ProvCat                                           42                   22
# oisst                                          19.57                 2.54
# etopo2                                           462                 3549
# solz                                            48.7                 51.2
# sat_rho_rc412                              0.0120876            0.0105251
# sat_rho_rc443                              0.0124167            0.0106362
# sat_rho_rc490                              0.0117387           0.00961355
# sat_rho_rc510                              0.0105793            0.0079127
# sat_rho_rc555                              0.0091096            0.0062244
# sat_rho_rc670                              0.0066549             0.004794
# chl_fluo                                       0.091                0.132
# chl_hplc                                         NaN                0.118
# chl                                            0.091                0.118
# log10_chl                                   -1.04096            -0.928118
# is_hplc                                        False                 True
#
#                                     2                       3  \
# datetime          2001-02-19 16:10:00     2002-01-22 13:45:00
# lat                            -61.29                 -60.999
# lon                            -56.29                 -56.498
# Biome                           Polar                   Polar
# BiomCat                             1                       1
# Province       Austral Polar Province  Austral Polar Province
# ProvCode                         APLR                    APLR
# Coastal                             0                       0
# ProvCat                            25                      25
# oisst                            0.78                    1.79
# etopo2                            330                    2193
# solz                             52.7                    45.9
# sat_rho_rc412              0.00444289              0.00586911
# sat_rho_rc443              0.00438667              0.00586578
# sat_rho_rc490              0.00424045              0.00553467
# sat_rho_rc510               0.0036856               0.0046431
# sat_rho_rc555               0.0026462               0.0033262
# sat_rho_rc670               0.0011773               0.0017469
# chl_fluo                          NaN                   0.707
# chl_hplc                          NaN                   0.614
# chl                               NaN                   0.614
# log10_chl                         NaN               -0.211832
# is_hplc                         False                    True
#
#                                                         4
# datetime                              1997-09-27 11:29:00
# lat                                               24.1392
# lon                                              -20.9995
# Biome                                              Trades
# BiomCat                                                 2
# Province       N. Atlantic Tropical Gyral Province (Trpg)
# ProvCode                                             NATR
# Coastal                                                 0
# ProvCat                                                33
# oisst                                               24.67
# etopo2                                               4369
# solz                                                   28
# sat_rho_rc412                                    0.009464
# sat_rho_rc443                                    0.008968
# sat_rho_rc490                                  0.00771911
# sat_rho_rc510                                   0.0059736
# sat_rho_rc555                                   0.0041613
# sat_rho_rc670                                   0.0025167
# chl_fluo                                              NaN
# chl_hplc                                            0.158
# chl                                                 0.158
# log10_chl                                       -0.801343
# is_hplc                                              True

# %%
df_.head().T
# Out:
#                                               0  \
# Coastal                                       1
# Biome                                   Coastal
# Province      Benguela Current Coastal Province
# ProvCode                                   BENG
# ProvCat                                       2
# sin_doy                               -0.984474
# cos_doy                                0.175531
# sin_minofday                           0.601815
# cos_minofday                          -0.798636
# x                                      0.700808
# y                                      0.328432
# z                                      0.633246
# log10_etopo2                            2.66464
# oisst                                     19.57
# solz                                       48.7
# PC1                                   0.0259902
# PC2                                  -0.0247272
# PC3                                 -0.00913884
# PC4                                 0.000774031
# PC5                                 -0.00279683
# PC6                                 1.46499e-17
# log10_chl                              -1.04096
#
#                                               1  \
# Coastal                                       1
# Biome                                   Coastal
# Province      Benguela Current Coastal Province
# ProvCode                                   BENG
# ProvCat                                       2
# sin_doy                                0.790946
# cos_doy                                0.611886
# sin_minofday                          -0.965926
# cos_minofday                          -0.258819
# x                                      0.222167
# y                                     -0.423148
# z                                       -0.8784
# log10_etopo2                            3.55011
# oisst                                      2.54
# solz                                       51.2
# PC1                                   0.0605998
# PC2                                  -0.0201292
# PC3                                 -0.00990766
# PC4                                 -0.00262289
# PC5                                 -0.00346263
# PC6                                 1.19292e-17
# log10_chl                             -0.928118
#
#                                               2  \
# Coastal                                       1
# Biome                                   Coastal
# Province      Benguela Current Coastal Province
# ProvCode                                   BENG
# ProvCat                                       2
# sin_doy                                0.758306
# cos_doy                                0.651899
# sin_minofday                          -0.887011
# cos_minofday                          -0.461749
# x                                      0.266604
# y                                     -0.399605
# z                                     -0.877062
# log10_etopo2                            2.51851
# oisst                                      0.78
# solz                                       52.7
# PC1                                    0.064018
# PC2                                   0.0216661
# PC3                                  0.00576502
# PC4                                  0.00714572
# PC5                                  0.00157663
# PC6                                 5.57757e-17
# log10_chl                                   NaN
#
#                                               3  \
# Coastal                                       1
# Biome                                   Coastal
# Province      Benguela Current Coastal Province
# ProvCode                                   BENG
# ProvCat                                       2
# sin_doy                                0.369725
# cos_doy                                0.929141
# sin_minofday                          -0.442289
# cos_minofday                          -0.896873
# x                                      0.267607
# y                                     -0.404279
# z                                     -0.874611
# log10_etopo2                            3.34104
# oisst                                      1.79
# solz                                       45.9
# PC1                                   0.0701748
# PC2                                   0.0131822
# PC3                                 0.000706246
# PC4                                  0.00317494
# PC5                                 -0.00053473
# PC6                                 3.72957e-17
# log10_chl                             -0.211832
#
#                                               4
# Coastal                                       1
# Biome                                   Coastal
# Province      Benguela Current Coastal Province
# ProvCode                                   BENG
# ProvCat                                       2
# sin_doy                               -0.997917
# cos_doy                              -0.0645084
# sin_minofday                           0.134851
# cos_minofday                          -0.990866
# x                                      0.851946
# y                                     -0.327023
# z                                      0.408955
# log10_etopo2                            3.64038
# oisst                                     24.67
# solz                                         28
# PC1                                     0.10574
# PC2                                -0.000820722
# PC3                                  0.00690341
# PC4                                 8.47773e-05
# PC5                                -0.000971181
# PC6                                 -6.2726e-17
# log10_chl                             -0.801343

# %%
df_.dropna().index
# Out:
# Int64Index([  0,   1,   3,   4,   5,   6,   7,   8,   9,  10,
#             ...
#             485, 486, 487, 488, 489, 490, 491, 492, 493, 494],
#            dtype='int64', length=423)

# %%
df_.loc[:, 'sin_doy':'PC6'].head().T
# Out:
#                          0             1             2             3  \
# sin_doy      -9.844738e-01  7.909457e-01  7.583058e-01  3.697245e-01
# cos_doy       1.755315e-01  6.118864e-01  6.518990e-01  9.291414e-01
# sin_minofday  6.018150e-01 -9.659258e-01 -8.870108e-01 -4.422887e-01
# cos_minofday -7.986355e-01 -2.588190e-01 -4.617486e-01 -8.968727e-01
# x             7.008083e-01  2.221672e-01  2.666040e-01  2.676069e-01
# y             3.284318e-01 -4.231483e-01 -3.996048e-01 -4.042793e-01
# z             6.332458e-01 -8.784004e-01 -8.770623e-01 -8.746112e-01
# log10_etopo2  2.664642e+00  3.550106e+00  2.518514e+00  3.341039e+00
# oisst         1.957000e+01  2.540000e+00  7.800000e-01  1.790000e+00
# solz          4.870000e+01  5.120000e+01  5.270000e+01  4.590000e+01
# PC1           2.599015e-02  6.059977e-02  6.401805e-02  7.017476e-02
# PC2          -2.472721e-02 -2.012915e-02  2.166605e-02  1.318215e-02
# PC3          -9.138836e-03 -9.907661e-03  5.765024e-03  7.062456e-04
# PC4           7.740306e-04 -2.622886e-03  7.145722e-03  3.174944e-03
# PC5          -2.796834e-03 -3.462634e-03  1.576635e-03 -5.347301e-04
# PC6           1.464986e-17  1.192921e-17  5.577568e-17  3.729566e-17
#
#                          4
# sin_doy      -9.979172e-01
# cos_doy      -6.450845e-02
# sin_minofday  1.348509e-01
# cos_minofday -9.908659e-01
# x             8.519460e-01
# y            -3.270229e-01
# z             4.089549e-01
# log10_etopo2  3.640382e+00
# oisst         2.467000e+01
# solz          2.800000e+01
# PC1           1.057401e-01
# PC2          -8.207225e-04
# PC3           6.903413e-03
# PC4           8.477726e-05
# PC5          -9.711815e-04
# PC6          -6.272597e-17

# %%
df_.to_pickle('./pickleJar/df_5_AllFeatures_w_Longhurst.pkl')
